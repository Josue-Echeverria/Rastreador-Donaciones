# %% [markdown]
# # Analisis de Contratos Post-Electorales
# ## Version Google Colab
#
# **Hipotesis:** Existe un aumento en la cantidad de contratos despues de las elecciones debido a que estos proveedores eran donantes de los partidos politicos.
#
# ### Estructura del notebook
#
# 1. **Importaciones y configuracion** - Todas las librerias y parametros de visualizacion.
# 2. **Montar Google Drive** - Acceso al almacenamiento en Drive.
# 3. **Rutas de configuracion** - Constantes con las rutas a los archivos de datos.
# 4. **Carga de datos** - Lectura de aportaciones, contratos y representantes juridicas.
# 5. **Exploracion inicial** - Revision rapida de la estructura y calidad de los datos cargados.
# 6. **Clase AnalizadorContratosElectorales** - Motor de analisis: detecta coincidencias entre donantes y proveedores, alertas temporales y visualizaciones por partido.
# 7. **Inicializar analizador** - Instanciacion con los DataFrames cargados.
# 8. **Generar reporte** - Reporte completo o filtrado por partido.
# 9. **Explorar alertas** - Tabla y estadisticas de las alertas detectadas.
# 10. **Exportar alertas** - Guardar resultados en Excel.
# 11. **Exportar top proveedores** - Genera archivo con los proveedores con mas contratos.
#
# ---

# %% [markdown]
# ## 1. Importaciones y configuracion
# Todas las librerias necesarias para analisis de datos, visualizacion y manejo de archivos.

# %%
# --- Librerias de datos ---
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from pathlib import Path
import glob
import os

# --- Librerias de visualizacion ---
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.patches import FancyArrowPatch
from matplotlib.dates import YearLocator, DateFormatter
import seaborn as sns

# --- Configuracion general ---
import warnings
warnings.filterwarnings('ignore')

plt.style.use('default')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

print("Librerias importadas correctamente")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 14
#      12 from matplotlib.patches import FancyArrowPatch
#      13 from matplotlib.dates import YearLocator, DateFormatter
# ---> 14 import seaborn as sns
#      16 # --- Configuracion general ---
#      17 import warnings
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\__init__.py:5
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
# ----> 5 from .relational import *  # noqa: F401,F403
#       6 from .regression import *  # noqa: F401,F403
#       7 from .categorical import *  # noqa: F401,F403
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\relational.py:21
# ...

# %% [markdown]
# ## 2. Montar Google Drive
# Necesario para acceder a los archivos almacenados en Drive desde Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')

print("Google Drive montado correctamente")

# %% [markdown]
# ## 3. Rutas de configuracion
# Constantes con las rutas a los archivos de datos. Ajustar segun la estructura de tu Drive.

# %%
# Rutas principales - ajustar segun tu estructura de Drive
RUTA_APORTACIONES = '/content/drive/MyDrive/Concurso/acumulado.xlsx'
CARPETA_CONTRATOS = '/content/drive/MyDrive/Concurso/Contratos'
RUTA_REPRESENTANTES = './representantes_juridicas.xlsx'

# Rutas de salida
RUTA_ALERTAS = '/content/drive/MyDrive/Concurso/alertas_6meses.xlsx'
RUTA_TOP_PROVEEDORES = '/content/drive/MyDrive/Concurso/contratos_top50_proveedores.xlsx'
RUTA_CONTRATOS_COMPLETO = '/content/drive/MyDrive/Concurso/contratos_completo.xlsx'

print("Rutas configuradas")

# %% [markdown]
# ## 4. Carga de datos
# Se cargan tres fuentes de datos:
# - **Aportaciones**: archivo unico con donaciones politicas (hoja 'BBDD').
# - **Contratos**: multiples archivos .xlsx en una carpeta (hoja 'Informacion de contratos').
# - **Representantes juridicas**: archivo local con datos de representantes.

# %%
# --- Cargar aportaciones ---
print("Cargando aportaciones...")
aportaciones = pd.read_excel(RUTA_APORTACIONES, sheet_name='BBDD')
print(f"  {len(aportaciones):,} registros de aportaciones cargados")
print(f"  Columnas: {list(aportaciones.columns)}")

# --- Cargar contratos desde multiples archivos ---
print(f"\nCargando contratos desde: {CARPETA_CONTRATOS}")

try:
    if not os.path.isdir(CARPETA_CONTRATOS):
        raise FileNotFoundError(f"Carpeta no encontrada: {CARPETA_CONTRATOS}")

    all_files = [
        os.path.join(CARPETA_CONTRATOS, f)
        for f in os.listdir(CARPETA_CONTRATOS)
        if f.lower().endswith('.xlsx')
    ]

    print(f"  Archivos encontrados: {len(all_files)}")

    dataframes = []
    for file in all_files:
        try:
            df = pd.read_excel(file, sheet_name='Informacion de contratos')
            dataframes.append(df)
            print(f"  + {os.path.basename(file)}: {len(df):,} contratos")
        except Exception as e:
            print(f"  x Error en {os.path.basename(file)}: {e}")

    if not dataframes:
        raise ValueError("No se pudieron cargar archivos validos.")

    contratos = pd.concat(dataframes, ignore_index=True)
    print(f"\n  Total: {len(contratos):,} contratos cargados")
    print(f"  Columnas: {list(contratos.columns[:5])}...")

except Exception as e:
    print(f"Error: {e}")

# --- Cargar representantes juridicas ---
print(f"\nCargando representantes juridicas...")
try:
    df_representantes = pd.read_excel(RUTA_REPRESENTANTES, sheet_name='Representantes')
    print(f"  {len(df_representantes):,} registros de representantes cargados")
except Exception as e:
    print(f"  Error al cargar representantes: {e}")
    df_representantes = None

print("\nCarga de datos finalizada")

# %% [markdown]
# ## 5. Exploracion inicial de representantes juridicas
# Revision rapida de la estructura, tipos de datos y valores nulos del DataFrame de representantes.

# %%
# Primeras filas y tipos de datos
if df_representantes is not None:
    print(df_representantes.head())
    df_representantes.info()
    print("\nValores nulos por columna:")
    print(df_representantes.isnull().sum())
else:
    print("No se cargo el DataFrame de representantes")

# %% [markdown]
# ## 6. Clase AnalizadorContratosElectorales
# Motor principal de analisis. Funcionalidades:
# - **Deteccion automatica de columnas**: busca nombres de columnas por palabras clave para adaptarse a distintos formatos de datos.
# - **Identificacion de coincidencias**: encuentra cedulas que aparecen como donantes y como proveedores del Estado.
# - **Alertas temporales**: detecta pares donacion-contrato que ocurren dentro de una ventana configurable (por defecto 6 meses).
# - **Visualizacion por partido**: grafico de barras con contratos mensuales de donantes de un partido, linea de tendencia, marcadores de elecciones y zonas de alerta.
# - **Reporte completo**: resumen textual de alertas, filtrable por partido.
# - **Exportacion a Excel**: guarda las alertas detectadas.

# %%
class AnalizadorContratosElectorales:
    """
    Clase para analizar la relacion temporal entre donaciones politicas y contratos gubernamentales.
    Detecta automaticamente las columnas relevantes en los DataFrames de entrada.
    """

    ELECCIONES_CR = [
        {'fecha': '2010-02-07', 'partido_ganador': 'LIBERACION NACIONAL', 'presidente': 'Laura Chinchilla'},
        {'fecha': '2014-02-02', 'partido_ganador': 'ACCION CIUDADANA', 'presidente': 'Luis Guillermo Solis'},
        {'fecha': '2018-04-01', 'partido_ganador': 'ACCION CIUDADANA', 'presidente': 'Carlos Alvarado'},
        {'fecha': '2022-04-03', 'partido_ganador': 'PROGRESO SOCIAL DEMOCRATICO', 'presidente': 'Rodrigo Chaves'}
    ]

    COLORES_PARTIDOS = {
        'LIBERACION NACIONAL': ['#0B5D1E', '#90EE90'],
        'ACCION CIUDADANA': ['#FFD700', '#FFA500'],
        'FRENTE AMPLIO': ['#DC143C', '#FF6B6B'],
        'UNIDAD SOCIAL CRISTIANA': ['#4169E1', '#87CEEB'],
        'MOVIMIENTO LIBERTARIO': ['#8B008B', '#DDA0DD'],
        'RESTAURACION NACIONAL': ['#00CED1', '#AFEEEE'],
        'PROGRESO SOCIAL DEMOCRATICO': ['#FF4500', '#FFB347'],
    }

    def __init__(self, df_contratos, df_aportaciones):
        """Inicializa el analizador con DataFrames ya cargados."""
        print("Preparando datos para analisis...")
        print("Analizando estructura de datos...\n")

        print("Contratos - columnas encontradas:")
        for i, col in enumerate(df_contratos.columns[:10], 1):
            print(f"  {i}. {col}")
        if len(df_contratos.columns) > 10:
            print(f"  ... y {len(df_contratos.columns) - 10} mas")

        print("\nAportaciones - columnas encontradas:")
        for i, col in enumerate(df_aportaciones.columns[:10], 1):
            print(f"  {i}. {col}")
        if len(df_aportaciones.columns) > 10:
            print(f"  ... y {len(df_aportaciones.columns) - 10} mas")

        self.df_contratos = self._preparar_contratos(df_contratos.copy())
        self.df_donaciones = self._preparar_donaciones(df_aportaciones.copy())
        self.df_elecciones = self._crear_df_elecciones()

        print(f"\nContratos procesados: {len(self.df_contratos):,}")
        print(f"Donaciones procesadas: {len(self.df_donaciones):,}")
        print(f"Proveedores unicos: {self.df_contratos['cedula_proveedor'].nunique():,}")
        print(f"Donantes unicos: {self.df_donaciones['cedula'].nunique():,}")

        self._identificar_coincidencias()

    def _encontrar_columna(self, df, palabras_clave, nombre_busqueda="columna"):
        """
        Busca una columna que contenga alguna de las palabras clave.

        Parametros
        ----------
        df : DataFrame
        palabras_clave : list de listas de palabras que deben estar presentes
        nombre_busqueda : str, nombre descriptivo para mensajes

        Retorna
        -------
        str o None, nombre de la columna encontrada
        """
        columnas = df.columns.tolist()

        for palabras in palabras_clave:
            for col in columnas:
                col_lower = col.lower()
                if all(palabra.lower() in col_lower for palabra in palabras):
                    print(f"  [OK] {nombre_busqueda}: '{col}'")
                    return col

        return None

    def _preparar_contratos(self, df):
        """Prepara y normaliza datos de contratos con deteccion automatica de columnas."""
        print("\nPreparando contratos...")

        # Buscar columna de fecha
        fecha_col = self._encontrar_columna(
            df,
            [['fecha', 'notif'], ['fecha'], ['date']],
            "Fecha"
        )

        if not fecha_col:
            raise ValueError(
                "No se encontro columna de fecha. "
                f"Columnas disponibles: {df.columns.tolist()}"
            )

        # Buscar columna de cedula del proveedor
        cedula_col = self._encontrar_columna(
            df,
            [
                ['cedula', 'proveedor'], ['cedula', 'proveedor'],
                ['cedula'], ['cedula'],
                ['identificacion', 'proveedor'],
                ['identificacion', 'proveedor'],
                ['id', 'proveedor']
            ],
            "Cedula Proveedor"
        )

        if not cedula_col:
            posibles = [col for col in df.columns
                       if any(x in col.lower() for x in ['cedula', 'cedula', 'identificacion', 'identificacion', 'id'])]

            if posibles:
                print(f"  [AVISO] Columnas posibles encontradas: {posibles}")
                print(f"  -> Usando: '{posibles[0]}'")
                cedula_col = posibles[0]
            else:
                raise ValueError(
                    f"No se encontro columna de cedula/identificacion del proveedor.\n"
                    f"Columnas disponibles: {df.columns.tolist()}\n"
                    f"Especifica manualmente: df_contratos.rename(columns={{'TU_COLUMNA': 'cedula_proveedor'}})"
                )

        # Buscar columnas opcionales
        identificador_col = self._encontrar_columna(
            df,
            [['identificador'], ['id', 'contrato'], ['numero', 'contrato'], ['nro', 'contrato']],
            "Identificador"
        )

        tipo_mod_col = self._encontrar_columna(
            df,
            [['tipo', 'modif'], ['modificacion']],
            "Tipo Modificacion"
        )

        # Renombrar columnas
        mapeo = {
            fecha_col: 'fecha_notificacion',
            cedula_col: 'cedula_proveedor'
        }
        if identificador_col:
            mapeo[identificador_col] = 'identificador'
        if tipo_mod_col:
            mapeo[tipo_mod_col] = 'tipo_modificacion'

        df = df.rename(columns=mapeo)

        # Convertir fecha y normalizar cedula
        df['fecha_notificacion'] = pd.to_datetime(df['fecha_notificacion'], errors='coerce')
        df['cedula_proveedor'] = df['cedula_proveedor'].astype(str).str.strip()

        antes = len(df)
        df = df.dropna(subset=['fecha_notificacion'])
        if len(df) < antes:
            print(f"  [AVISO] Eliminadas {antes - len(df)} filas con fecha invalida")

        return df

    def _preparar_donaciones(self, df):
        """Prepara y normaliza datos de donaciones con deteccion automatica de columnas."""
        print("\nPreparando donaciones...")

        partido_col = self._encontrar_columna(
            df,
            [['partido', 'politico'], ['partido', 'politico'], ['partido'], ['party']],
            "Partido"
        )
        if not partido_col:
            raise ValueError(
                f"No se encontro columna de partido politico.\n"
                f"Columnas disponibles: {df.columns.tolist()}"
            )

        fecha_col = self._encontrar_columna(
            df,
            [['fecha'], ['date'], ['fecha', 'donacion'], ['fecha', 'aportacion']],
            "Fecha"
        )
        if not fecha_col:
            raise ValueError(
                f"No se encontro columna de fecha.\n"
                f"Columnas disponibles: {df.columns.tolist()}"
            )

        cedula_col = self._encontrar_columna(
            df,
            [['cedula'], ['cedula'], ['identificacion'], ['identificacion'], ['id']],
            "Cedula"
        )
        if not cedula_col:
            raise ValueError(
                f"No se encontro columna de cedula.\n"
                f"Columnas disponibles: {df.columns.tolist()}"
            )

        monto_col = self._encontrar_columna(
            df, [['monto'], ['valor'], ['amount'], ['cantidad']], "Monto"
        )
        nombre_col = self._encontrar_columna(
            df, [['nombre', 'contribuyente'], ['nombre'], ['donante'], ['aportante']], "Nombre"
        )

        mapeo = {
            partido_col: 'partido_politico',
            fecha_col: 'fecha',
            cedula_col: 'cedula'
        }
        if monto_col:
            mapeo[monto_col] = 'monto'
        if nombre_col:
            mapeo[nombre_col] = 'nombre_del_contribuyente'

        df = df.rename(columns=mapeo)

        df['fecha'] = pd.to_datetime(df['fecha'], errors='coerce')
        df['cedula'] = df['cedula'].astype(str).str.replace('-', '').str.strip()

        antes = len(df)
        df = df.dropna(subset=['fecha'])
        if len(df) < antes:
            print(f"  [AVISO] Eliminadas {antes - len(df)} filas con fecha invalida")

        return df

    def _crear_df_elecciones(self):
        """Crea DataFrame con informacion de elecciones de Costa Rica."""
        df = pd.DataFrame(self.ELECCIONES_CR)
        df['fecha'] = pd.to_datetime(df['fecha'])
        return df

    def _identificar_coincidencias(self):
        """Identifica cedulas que aparecen como donantes Y como proveedores."""
        cedulas_contratos = set(self.df_contratos['cedula_proveedor'].unique())
        cedulas_donaciones = set(self.df_donaciones['cedula'].unique())
        self.coincidencias = cedulas_contratos & cedulas_donaciones
        print(f"\nCoincidencias encontradas: {len(self.coincidencias)} cedulas son DONANTES y PROVEEDORES")

    def detectar_alertas_temporales(self, ventana_meses=6, solo_coincidencias=True):
        """
        Detecta pares (donacion, contrato) cuya diferencia temporal es menor a la ventana indicada.

        Parametros
        ----------
        ventana_meses : int, meses maximos de diferencia (default 6)
        solo_coincidencias : bool, si True solo analiza cedulas que son donantes y proveedores

        Retorna
        -------
        DataFrame con las alertas detectadas
        """
        print(f"\nDetectando alertas temporales (ventana: {ventana_meses} meses)...")

        alertas = []
        cedulas_analizar = self.coincidencias if solo_coincidencias else set(self.df_donaciones['cedula'].unique())

        for cedula in cedulas_analizar:
            donaciones = self.df_donaciones[self.df_donaciones['cedula'] == cedula]
            contratos_ced = self.df_contratos[self.df_contratos['cedula_proveedor'] == cedula]

            if len(contratos_ced) == 0:
                continue

            for _, donacion in donaciones.iterrows():
                for _, contrato in contratos_ced.iterrows():
                    diferencia_dias = abs((contrato['fecha_notificacion'] - donacion['fecha']).days)
                    diferencia_meses = diferencia_dias / 30.44

                    if diferencia_meses <= ventana_meses:
                        alerta = {
                            'cedula': cedula,
                            'fecha_donacion': donacion['fecha'],
                            'fecha_contrato': contrato['fecha_notificacion'],
                            'partido_donado': donacion.get('partido_politico', 'N/A'),
                            'monto_donacion': donacion.get('monto', 0),
                            'diferencia_dias': diferencia_dias,
                            'diferencia_meses': diferencia_meses,
                            'donacion_antes': donacion['fecha'] < contrato['fecha_notificacion'],
                            'anio_donacion': donacion['fecha'].year,
                            'anio_contrato': contrato['fecha_notificacion'].year
                        }

                        if 'nombre_del_contribuyente' in donacion:
                            alerta['nombre_contribuyente'] = donacion['nombre_del_contribuyente']
                        if 'identificador' in contrato:
                            alerta['identificador_contrato'] = contrato['identificador']
                        if 'tipo_modificacion' in contrato:
                            alerta['tipo_modificacion'] = contrato['tipo_modificacion']

                        alertas.append(alerta)

        df_alertas = pd.DataFrame(alertas)

        if len(df_alertas) > 0:
            print(f"  Total de alertas detectadas: {len(df_alertas)}")
        else:
            print("  No se detectaron alertas en la ventana especificada")

        return df_alertas

    def visualizar_linea_temporal_partido(self, partido, fecha_inicio=None, fecha_fin=None,
                                          figsize=(10, 5), mostrar_alertas=True,
                                          ventana_alerta_meses=6):
        """
        Grafico de barras con contratos mensuales de donantes de un partido especifico.
        Incluye linea de tendencia, marcadores de elecciones y zonas de alerta.

        Parametros
        ----------
        partido : str, nombre del partido politico
        fecha_inicio, fecha_fin : str o datetime, rango de fechas opcional
        figsize : tuple, tamano de la figura (default (10, 5))
        mostrar_alertas : bool, superponer zonas de alerta en el grafico
        ventana_alerta_meses : int, ventana de alertas en meses

        Retorna
        -------
        (fig, ax) de matplotlib
        """
        partido_upper = partido.upper()

        donaciones_partido = self.df_donaciones[
            self.df_donaciones['partido_politico'].str.upper() == partido_upper
        ]
        cedulas_partido = set(donaciones_partido['cedula'].unique())

        contratos_donantes = self.df_contratos[
            self.df_contratos['cedula_proveedor'].isin(cedulas_partido)
        ].copy()

        if fecha_inicio:
            contratos_donantes = contratos_donantes[
                contratos_donantes['fecha_notificacion'] >= fecha_inicio
            ]
        if fecha_fin:
            contratos_donantes = contratos_donantes[
                contratos_donantes['fecha_notificacion'] <= fecha_fin
            ]

        if len(contratos_donantes) == 0:
            print(f"No hay contratos de donantes de {partido} en el periodo seleccionado")
            return None, None

        contratos_mensuales = contratos_donantes.groupby(
            pd.Grouper(key='fecha_notificacion', freq='M')
        ).size()

        if fecha_inicio and fecha_fin:
            idx_completo = pd.date_range(start=fecha_inicio, end=fecha_fin, freq='M')
            contratos_mensuales = contratos_mensuales.reindex(idx_completo, fill_value=0)

        alertas = None
        if mostrar_alertas:
            alertas_todas = self.detectar_alertas_temporales(ventana_alerta_meses)
            if len(alertas_todas) > 0 and 'partido_donado' in alertas_todas.columns:
                alertas = alertas_todas[
                    alertas_todas['partido_donado'].str.upper() == partido_upper
                ]

        fig, ax = plt.subplots(figsize=figsize)
        colores = self.COLORES_PARTIDOS.get(partido_upper, ['#4A90E2', '#E94F9E'])

        x = contratos_mensuales.index
        y = contratos_mensuales.values

        y1 = y * 0.65
        y2 = y * 0.35
        width = 20
        ax.bar(x, y1, color=colores[0], alpha=0.85, width=width)
        ax.bar(x, y2, bottom=y1, color=colores[1], alpha=0.85, width=width)

        # Linea de tendencia
        if len(x) > 3:
            x_numeric = np.arange(len(x))
            mask = y > 0
            if mask.sum() > 2:
                z = np.polyfit(x_numeric[mask], y[mask], min(2, mask.sum()-1))
                p = np.poly1d(z)
                y_trend = p(x_numeric)
                ax.plot(x, y_trend, color='red', linewidth=4, zorder=5, alpha=0.8)

        # Marcadores de elecciones
        elecciones_periodo = self.df_elecciones.copy()
        if fecha_inicio:
            elecciones_periodo = elecciones_periodo[elecciones_periodo['fecha'] >= fecha_inicio]
        if fecha_fin:
            elecciones_periodo = elecciones_periodo[elecciones_periodo['fecha'] <= fecha_fin]

        for _, eleccion in elecciones_periodo.iterrows():
            fecha_elec = eleccion['fecha']
            if fecha_elec >= x.min() and fecha_elec <= x.max():
                y_max = ax.get_ylim()[1]
                arrow = FancyArrowPatch(
                    (fecha_elec, y_max * 0.88), (fecha_elec, y_max * 0.3),
                    arrowstyle='->', mutation_scale=40, linewidth=4,
                    color='#CC0000', zorder=10
                )
                ax.add_patch(arrow)
                ax.text(fecha_elec, y_max * 0.95, 'ELECCION',
                       ha='center', fontsize=12, fontweight='bold',
                       bbox=dict(boxstyle='round,pad=0.5', facecolor='white',
                                edgecolor='red', linewidth=2))

        # Zonas de alerta
        if alertas is not None and len(alertas) > 0:
            print(f"  Mostrando {len(alertas)} alertas en el grafico")
            for _, al in alertas.iterrows():
                if al['fecha_contrato'] >= x.min() and al['fecha_contrato'] <= x.max():
                    f_ini = min(al['fecha_donacion'], al['fecha_contrato'])
                    f_end = max(al['fecha_donacion'], al['fecha_contrato'])
                    ax.axvspan(f_ini, f_end, alpha=0.15, color='yellow', zorder=1,
                              linewidth=2, edgecolor='orange', linestyle='--')

        ax.set_title(f'{partido.title()}', fontsize=26, fontweight='bold', pad=20)
        ax.set_xlabel('Periodo', fontsize=14, fontweight='bold')
        ax.set_ylabel('Cantidad de Contratos\n(Donantes del Partido)', fontsize=14, fontweight='bold')
        ax.xaxis.set_major_locator(YearLocator())
        ax.xaxis.set_major_formatter(DateFormatter('%Y'))
        ax.grid(axis='y', alpha=0.3, linestyle='--', linewidth=0.5)
        ax.set_axisbelow(True)
        ax.set_facecolor('#F5F5F5')
        fig.patch.set_facecolor('white')

        total_contratos = len(contratos_donantes)
        donantes_unicos = len(cedulas_partido)
        texto_stats = f"Contratos: {total_contratos:,} | Donantes: {donantes_unicos:,}"
        ax.text(0.02, 0.98, texto_stats, transform=ax.transAxes, fontsize=10,
               verticalalignment='top',
               bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))

        plt.tight_layout()
        return fig, ax

    def generar_reporte_completo(self, ventana_alerta_meses=6, partido=None):
        """
        Genera un reporte textual con alertas temporales y coincidencias.

        Parametros
        ----------
        ventana_alerta_meses : int, ventana temporal para detectar alertas (default 6)
        partido : str, nombre del partido politico para filtrar (opcional)

        Retorna
        -------
        DataFrame con las alertas (o la ultima alerta si se filtro por partido)
        """
        print("\n" + "=" * 90)
        if partido:
            print(f"REPORTE: ANALISIS DE CONTRATOS POST-ELECTORALES - {partido.upper()}")
        else:
            print("REPORTE COMPLETO: ANALISIS DE CONTRATOS POST-ELECTORALES")
        print("=" * 90)

        print(f"\n{'ALERTAS TEMPORALES':^90}")
        print("-" * 90)
        alertas = self.detectar_alertas_temporales(ventana_alerta_meses)

        if partido and len(alertas) > 0:
            partido_upper = partido.upper()
            alertas = alertas[alertas['partido_donado'].str.upper() == partido_upper]
            print(f"Filtrado por partido: {partido.upper()}")

        if len(alertas) > 0:
            print(f"\nTotal de alertas detectadas: {len(alertas)}")

            if not partido:
                print(f"\n{'Alertas por partido:':^90}")
                alertas_por_partido = alertas['partido_donado'].value_counts()
                for p, cantidad in alertas_por_partido.head(10).items():
                    print(f"  - {p}: {cantidad} alertas")

            num_alertas_mostrar = len(alertas) if partido else 10
            titulo = f"Todas las alertas encontradas ({len(alertas)})" if partido else "Top 10 casos mas sospechosos"

            print(f"\n{titulo:^90}")
            print("-" * 90)

            top_alertas = alertas.nsmallest(num_alertas_mostrar, 'diferencia_dias')

            for idx, (_, alerta) in enumerate(top_alertas.iterrows(), 1):
                print(f"\n{idx}. Cedula: {alerta['cedula']}")
                if 'nombre_contribuyente' in alerta and pd.notna(alerta['nombre_contribuyente']):
                    print(f"   Nombre: {alerta['nombre_contribuyente']}")
                print(f"   Partido: {alerta['partido_donado']}")
                print(f"   Donacion: {alerta['fecha_donacion'].strftime('%Y-%m-%d')} "
                      f"(CRC {alerta['monto_donacion']:,.0f})")
                print(f"   Contrato: {alerta['fecha_contrato'].strftime('%Y-%m-%d')}")
                if 'identificador_contrato' in alerta and pd.notna(alerta['identificador_contrato']):
                    print(f"   ID: {alerta['identificador_contrato']}")
                print(f"   Diferencia: {int(alerta['diferencia_dias'])} dias "
                      f"({alerta['diferencia_meses']:.1f} meses)")
                secuencia = 'Donacion -> Contrato [!]' if alerta['donacion_antes'] else 'Contrato -> Donacion'
                print(f"   Secuencia: {secuencia}")
        else:
            if partido:
                print(f"\nNo se detectaron alertas para {partido.upper()}")
            else:
                print("\nNo se detectaron alertas")

        if not partido:
            print(f"\n\n{'RESUMEN DE COINCIDENCIAS':^90}")
            print("-" * 90)
            print(f"\nTotal de cedulas que son DONANTES y PROVEEDORES: {len(self.coincidencias)}")
            contratos_coincidencias = self.df_contratos[
                self.df_contratos['cedula_proveedor'].isin(self.coincidencias)
            ]
            print(f"Contratos otorgados a estos proveedores: {len(contratos_coincidencias):,}")

        print("\n" + "=" * 90)
        return alertas

    def exportar_alertas_excel(self, alertas, ruta_archivo='alertas_temporales.xlsx'):
        """
        Exporta las alertas a un archivo Excel ordenadas por diferencia temporal.

        Parametros
        ----------
        alertas : DataFrame con alertas
        ruta_archivo : str, ruta de salida

        Retorna
        -------
        str con la ruta del archivo o None si no hay alertas
        """
        if len(alertas) == 0:
            print("No hay alertas para exportar")
            return None

        alertas_ordenadas = alertas.sort_values('diferencia_dias')
        alertas_ordenadas.to_excel(ruta_archivo, index=False)
        print(f"Alertas exportadas a: {ruta_archivo}")
        return ruta_archivo


print("Sistema de Analisis V2 cargado")
print("  - Deteccion automatica de columnas")
print("  - Filtro por partido politico")
print("  - Graficos tamano (10, 5) por defecto")
print("  - Todas las funcionalidades implementadas")

# %% [markdown]
# ## 7. Inicializar analizador
# Se crea la instancia con los DataFrames de contratos y aportaciones cargados en la seccion 4.

# %%
analizador = AnalizadorContratosElectorales(contratos, aportaciones)

# %% [markdown]
# ## 8. Generar reporte
# Reporte completo de alertas temporales, filtrable por partido. Cambia el parametro `partido` o ponlo en `None` para ver todos.

# %%
# Generar reporte con ventana de 6 meses, filtrado por partido
alertas = analizador.generar_reporte_completo(ventana_alerta_meses=6, partido='ACCION CIUDADANA')

# %% [markdown]
# ## 9. Explorar alertas detectadas
# Tabla con las primeras alertas, distribucion por partido y estadisticas de diferencias temporales.

# %%
if len(alertas) > 0:
    print(f"Total de alertas: {len(alertas)}\n")

    # Primeras alertas
    display(alertas.head(10))

    # Distribucion por partido
    print("\n\nAlertas por partido:")
    display(alertas['partido_donado'].value_counts())

    # Estadisticas basicas
    print("\n\nEstadisticas de diferencias temporales:")
    print(f"Diferencia minima: {alertas['diferencia_dias'].min():.0f} dias")
    print(f"Diferencia maxima: {alertas['diferencia_dias'].max():.0f} dias")
    print(f"Diferencia promedio: {alertas['diferencia_dias'].mean():.1f} dias")
    print(f"Diferencia mediana: {alertas['diferencia_dias'].median():.1f} dias")
else:
    print("No se detectaron alertas en el periodo")

# %% [markdown]
# ## 11. Exportar top proveedores
# Carga todos los contratos, identifica los proveedores con mas contratos y exporta dos archivos:
# - Contratos filtrados por top proveedores.
# - Dataset completo de contratos.

# %%
# Cargar todos los archivos Excel de contratos
archivos = glob.glob(CARPETA_CONTRATOS + '/*.xlsx')
print(f"Archivos encontrados: {len(archivos)}")

dfs = []
for archivo in archivos:
    try:
        df = pd.read_excel(archivo)
        if 'Cedula Proveedor' in df.columns and 'Nro Contrato' in df.columns:
            dfs.append(df[['Nro Contrato', 'Cedula Proveedor', 'Identificador']].copy())
        print(f"  + Cargado: {Path(archivo).name}")
    except Exception as e:
        print(f"  x Error en {Path(archivo).name}: {e}")

df_completo = pd.concat(dfs, ignore_index=True)
print(f"\nTotal de registros: {len(df_completo)}")

# Limpiar datos
df_completo = df_completo.dropna(subset=['Cedula Proveedor'])
df_completo['Cedula Proveedor'] = df_completo['Cedula Proveedor'].astype(str)

# Proveedores ordenados por numero de contratos
top_proveedores = df_completo['Cedula Proveedor'].value_counts()
print(f"\nProveedores por cantidad de contratos:")
print(top_proveedores)

# Filtrar por top proveedores
df_filtrado = df_completo[df_completo['Cedula Proveedor'].isin(top_proveedores.index)]

# Guardar archivo filtrado
df_filtrado.to_excel(RUTA_TOP_PROVEEDORES, index=False, engine='openpyxl')
print(f"\nArchivo guardado: {RUTA_TOP_PROVEEDORES}")
print(f"  Registros guardados: {len(df_filtrado):,}")
print(f"  Proveedores incluidos: {df_filtrado['Cedula Proveedor'].nunique()}")
print(f"  Contratos unicos: {df_filtrado['Nro Contrato'].nunique():,}")

# Guardar dataset completo
df_completo.to_excel(RUTA_CONTRATOS_COMPLETO, index=False, engine='openpyxl')
print(f"\nDataset completo guardado: {RUTA_CONTRATOS_COMPLETO}")
print(f"  Registros totales: {len(df_completo):,}")

# %%
import os
import pandas as pd
import warnings
import pandas as pd
archivos_xlsx = [
    os.path.join("Contratos", f)
    for f in os.listdir("Contratos")
    if f.lower().endswith('.xlsx')
]
todos_los_dfs = []
total_registros = 0
registro = {}

for i, archivo in enumerate(archivos_xlsx, 1):
    try:
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
        df_archivo = pd.read_excel(archivo, sheet_name='Informacion de contratos')
        
        registros_archivo = len(df_archivo)
        todos_los_dfs.append(df_archivo)
        total_registros += registros_archivo
        
        registro[archivo] = registros_archivo
        
    except Exception as e:
        print(f"  {i:2d}. ERROR en {os.path.basename(archivo)}: {e}")

# Unir todos los DataFrames
if todos_los_dfs:
    df_unificado = pd.concat(todos_los_dfs, ignore_index=True)
    
    # Guardar archivo unificado
    ruta_salida = 'contratos2.xlsx'
    df_unificado.to_excel(ruta_salida, index=False, engine='openpyxl')
    
    print(registro)

    # Resumen final
    print(f"\n{'='*50}")
    print(f"PROCESO COMPLETADO:")
    print(f"  Archivos procesados: {len(todos_los_dfs)}")
    print(f"  Total de registros: {total_registros:,}")
    print(f"  Registros en archivo final: {len(df_unificado):,}")
    print(f"  Columnas preservadas: {len(df_unificado.columns)}")
    print(f"  Archivo guardado en: {ruta_salida}")
    print(f"{'='*50}")
    
else:
    print("\nNo se pudieron cargar archivos validos.")
# Out:
# C:\Users\Asus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Asus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# C:\Users\Asus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...
